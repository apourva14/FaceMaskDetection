# %% [markdown]
# # Using Convulational Neural network to detect face mask

# %% [markdown]
# Import and installing all the files nescessary for this project.

# %% [markdown]
# Installing cv2 was a tough job to install along the latest version of python 3.8.3.
# So to do that and install opencv, we are going to use some commands that I kinda figured it out on my own.

# %% [markdown]
# 1.brew cask anaconda

# %% [markdown]
# 2.export PATH="/usr/local/anaconda3/bin:$PATH"

# %% [markdown]
# Now all the conda references will work.

# %% [markdown]
# 3.conda create --name ComputerVision python=3.8

# %% [markdown]
# 4.pip install opencv-python

# %% [markdown]
# To activate:

# %% [markdown]
# 5.source activate ComputerVision

# %% [markdown]
# 6.jupyter notebook

# %%
#import necessary stuff
import cv2
import os
import zipfile

# %%
pip install -q tensorflow tensorflow-datasets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras

# %% [markdown]
# # Uploading and extracting the zipped file and it's information.

# %% [markdown]
# The dataset is provided by Prajna Bhandary which is available on github

# %%
file_name= 'dataset.zip'

# %%
import zipfile
with zipfile.ZipFile(file_name, 'r') as zip_ref:
    zip_ref.extractall('dataset')

# %% [markdown]
# After extracting, the below cell will detect the folders present in the dataset file.
# And then separating 'with_mask' and 'without_mask' folder by labeling them.

# %%
data_path='dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

# %%
label_dict=dict(zip(categories,labels))

# %%
print(label_dict)
print(categories)
print(labels)
# Out:
# {'without mask': 0, 'with mask': 1, '.ipynb_checkpoints': 2}
# ['without mask', 'with mask', '.ipynb_checkpoints']
# [0, 1, 2]

# %% [markdown]
# Resizing the image.

# %%
img_size=100
data=[]
target=[]

# %% [markdown]
# The below cell will read the images present in the folders. We'll then convert it into grayscale image. The Exception occurs due a python file present in this folder but not a thing to be worried about.

# %%
for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            #Coverting the image into gray scale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the gray scale into 100x100, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)

        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image
# Out:
# Exception: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-2rx9f0ng/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Exception: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-2rx9f0ng/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Exception: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-2rx9f0ng/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Exception: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-2rx9f0ng/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# ...

# %%
import tensorflow as tf

# %%
import keras

# %%
INIT_LR = 1e-4
EPOCHS = 20
BS = 32

# %%
import numpy as np

data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

# %%
pip install keras-utils
# Out:
# ...
#   Created wheel for keras-utils: filename=keras_utils-1.0.13-py3-none-any.whl size=2655 sha256=b98ac9cfb49e3cfe0ed63f1c54a7a1f92df2ebbaa1ccbeb5a7b4cac974f67b1e
#   Stored in directory: /Users/singh/Library/Caches/pip/wheels/2f/e9/19/d3d310a06735013bf467216222ebb92b1158c5d3ae006bf92a
# Successfully built keras-utils
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
import keras_utils

# %%
pip install np_utils
# Out:
# ...
#      |████████████████████████████████| 61 kB 202 kB/s eta 0:00:01
# ...
#   Created wheel for np-utils: filename=np_utils-0.5.12.1-py3-none-any.whl size=57126 sha256=277f9bc56d7db15b46b7d377db471695edbb2df0af71990ef07963a94a9fc157
#   Stored in directory: /Users/singh/Library/Caches/pip/wheels/57/18/82/402fcaf521e84dfa67b077aea34d225fc32ce6085e2cb8dda6
# Successfully built np-utils
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.utils import to_categorical

# %%
new_target=np_utils.to_categorical(target)

# %%
np.save('data',data)
np.save('target',new_target)

# %% [markdown]
# # Building convulational neural network for this dataset

# %%
data=np.load('data.npy')
target=np.load('target.npy')

# %% [markdown]
# Building the layers and patterns for cnn

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

#The first CNN layer!
model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#The second convolution layer!
model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Flatten layer to stack the output convolutions from second convolution layer
model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(50,activation='relu'))

model.add(Dense(2,activation='softmax'))


model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # A summary on our neural network.

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_8 (Conv2D)            (None, 98, 98, 200)       2000
# _________________________________________________________________
# activation_8 (Activation)    (None, 98, 98, 200)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 49, 49, 200)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 47, 47, 100)       180100
# _________________________________________________________________
# activation_9 (Activation)    (None, 47, 47, 100)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 23, 23, 100)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 52900)             0
# ...

# %% [markdown]
# The convulationnal layers has reduced the size of feature maps by a bit due to padding, and each pooling layer halves the dimensions.

# %% [markdown]
# # Training and testing the data

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1, stratify=target, random_state=42)

# %%
opt=Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')

# %%
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)

# %%
print(model.evaluate(test_data,test_target))
